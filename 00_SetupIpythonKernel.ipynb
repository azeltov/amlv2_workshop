# %%
CONDA_ENV_NAME = 'amldemo_3_10'
KERNEL_DISPLAY_NAME = 'Aml SDKv2 Py3_10'

# %%
# %conda env create -f workstation_env.yml
# Out:
# ...
# Solving environment: done
#
# ...
# mkl_fft-1.3.1        | 180 KB    |                                       |   0%
# zlib-1.2.13          | 103 KB    |                                       |   0%
#
# pandas-1.1.5         | 8.5 MB    |                                       |   0%
#
#
# setuptools-66.0.0    | 1.2 MB    |                                       |   0%
#
#
#
# scipy-1.7.1          | 16.6 MB   |                                       |   0%
#
#
#
#
# wheel-0.38.4         | 63 KB     |                                       |   0%
#
#
#
#
#
# _openmp_mutex-5.1    | 21 KB     |                                       |   0%
#
#
#
#
#
#
# pytz-2022.7          | 209 KB    |                                       |   0%
#
#
#
#
#
#
#
# python-dateutil-2.8. | 233 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# scikit-learn-0.24.2  | 5.4 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# ...

# %% [markdown]
# %conda create --name {CONDA_ENV_NAME}  python=3.8 -y

# %% [markdown]
# %conda install -n {CONDA_ENV_NAME} ipykernel -y

# %%
# !/anaconda/envs/{CONDA_ENV_NAME}/bin/python -m ipykernel install --user --name {CONDA_ENV_NAME} --display-name "{KERNEL_DISPLAY_NAME}"
# Out:
# /bin/bash: /anaconda/envs/amldemo_3_10/bin/python: No such file or directory

# %%
# %conda env update --file workstation_env.yml --prune
# Out:
# ...
# Solving environment: done
# Installing pip dependencies: |
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# /
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# \
